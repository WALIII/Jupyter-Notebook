# %%
## d121615_Plot_Sonogram

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.image as im

dt = 0.0005
t = np.arange(0.0, 20.0, dt)
s1 = np.sin(2*np.pi*100*t)
s2 = 2*np.sin(2*np.pi*400*t)

# create a transient "chirp"
mask = np.where(np.logical_and(t > 10, t < 12), 1.0, 0.0)
s2 = s2 * mask

# add some noise into the mix
nse = 0.01*np.random.random(size=len(t))

x = s1 + s2 + nse  # the signal
NFFT = 1024       # the length of the windowing segments
Fs = int(1.0/dt)  # the sampling frequency

# Pxx is the segments x freqs array of instantaneous power, freqs is
# the frequency vector, bins are the centers of the time bins in which
# the power is computed, and im is the matplotlib.image.AxesImage
# instance

ax1 = plt.subplot(211)
plt.plot(t, x)
plt.subplot(212, sharex=ax1)
Pxx, freqs, bins, im = plt.specgram(x, NFFT=NFFT, Fs=Fs, noverlap=900,cmap=plt.cm.gist_heat)

# %%
# %matplotlib inline

# %%
ax1 = plt.subplot(211)
plt.plot(t, x)
plt.subplot(212, sharex=ax1)
Pxx, freqs, bins, im = plt.specgram(x, NFFT=NFFT, Fs=Fs, noverlap=900,cmap=plt.cm.gist_heat)

# %%
#Load an example Sonogram:

# %%
import matplotlib.image as mpimg
IM1=mpimg.imread("/Users/ARGO/Documents/DATA/ABA_current/LNY13/2015-08-04/gif/2015-08-04 10 45 51.gif",format=None)

# %%
# Plot it...
imgplot = plt.imshow(IM1)

# %%
# that's default image size for this interactive session.
import matplotlib.pylab as pylab
pylab.rcParams['figure.figsize'] = 16, 12

# %%
# Plot the new, resized sonogram.
imgplot = plt.imshow(IM1)

# %%
# If we had neural data that we wnated to compare this too:
ax1 = plt.subplot(211)
plt.imshow(IM1)
plt.subplot(212)
Pxx, freqs, bins, im = plt.specgram(x, NFFT=NFFT, Fs=Fs, noverlap=900,cmap=plt.cm.gist_heat)

# %%
# or for a raster:
