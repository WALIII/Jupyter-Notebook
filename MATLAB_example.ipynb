% %% [markdown]
% # Matlab Example in Jupyter Notebook
%         by WALIII
%         on 01/03/16
% Just a simple example of using matlab within the jupyter notebook

% %%
x = 10;

% %%
x = 1:10;

% %%
y = x.^2
% Out:
% y =
%
%      1     4     9    16    25    36    49    64    81   100

% %%
figure(); plot(x,y)
